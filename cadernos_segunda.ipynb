# %% [markdown]
# ### Transformação do pdf em uma unica string gigante

# %%
# %load_ext autoreload
# %autoreload 2
import funcoes as fc
import os
from tqdm import tqdm
diretorio_pdfs = "cadernos"
df = pd.DataFrame()
for arquivo in tqdm(os.listdir(diretorio_pdfs)):
    df_novo = fc.parsear_caderno_segunda(diretorio_pdfs + '/' + arquivo)
    df_novo['arquivo_origem'] = arquivo
    df = pd.concat([df, df_novo])    
df
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [01:50<00:00, 22.07s/it]
#                codigo_processo  \
# 0    1019721-53.2016.8.26.0100
# 1    1001493-53.2017.8.26.0081
# 2    1010985-65.2015.8.26.0008
# 3    1015858-61.2017.8.26.0001
# 4    0072004-67.2012.8.26.0114
# 5    1014352-44.2014.8.26.0037
# 6    1004457-51.2016.8.26.0114
# 7    0011085-81.2011.8.26.0071
# 8    1000219-97.2018.8.26.0411
# 9    1073544-39.2016.8.26.0100
# 10   0043306-65.2013.8.26.0001
# 11   0217508-83.2011.8.26.0100
# 12   1003501-56.2017.8.26.0322
# 13   1004074-66.2016.8.26.0278
# 14   1004260-41.2017.8.26.0218
# 15   1030893-58.2017.8.26.0002
# 16   1040399-81.2015.8.26.0114
# 17   1000670-28.2017.8.26.0486
# 18   1000410-77.2018.8.26.0368
# 19   1004617-24.2014.8.26.0348
# 20   1005274-02.2017.8.26.0011
# 21   1009773-29.2015.8.26.0066
# ...
