# %% [markdown]
# ### Transformação do pdf em uma unica string gigante

# %%
# %load_ext autoreload
# %autoreload 2
from tika import parser
import re
import pandas as pd
raw = parser.from_file('cadernos/2018_08_07.pdf')
print('Documento lido')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Documento lido

# %% [markdown]
# ### Armazenamento dos processos em uma lista de strings

# %%
#remove quebras de páginas
reg_quebra_pagina = re.compile('(\\n){4}Publicação Oficial do Tribunal de Justiça do Estado de São Paulo - Lei Federal nº 11.419/06, art. 4º(\\n){2}Disponibilização:.*?(\\n){2}')
conteudo_pdf = reg_quebra_pagina.sub(' ', raw['content'])
#quebra o documento pdf em uma lista de processos onde cada elemento é o conteúdo de um processo
regex_processos = re.compile('(?<=Nº )\d{7}-\d{2}.\d{4}.\d.\d{2}.\d{4}.*?(?=\n{2})', re.DOTALL)
lista_processos = regex_processos.findall(conteudo_pdf)

# %% [markdown]
# ### Extração das entidades dos processos

# %%
regex_processo = re.compile(r'\d{7}-\d{2}.\d{4}.\d.\d{2}.\d{4}', re.DOTALL)
regex_parte_ativa = re.compile(r'(?<=Apelante:).*?(?=-)|(?<=Requerente:).*?(?=-)|(?<=Agravante:).*?(?=-)', re.DOTALL)
regex_parte_passiva = re.compile(r'(?<=Apelad[o|a]:).*?(?=-)|(?<=Requeri[o|a]:).*?(?=-)|(?<=Agravad[o|a]:).*?(?=-)', re.DOTALL)
regex_parte_neutra = re.compile(r'(?<=Apd[o|a]\/Apte:).*?(?=-)|(?<=Apte\/Apd[o|a]:).*?(?=-)')
regex_advogados = re.compile(r'(?<=Advs:).*|(?<=Advogad[o|a]:).*', re.DOTALL)

lista_apelacoes_danos_morais = []

for i, processo in enumerate(lista_processos, 0):
    if re.search('- Apelação -', processo, 
                 re.MULTILINE) != None and re.search('danos morais', 
                                                     processo.lower(),
                                                     re.MULTILINE) != None:        
        try:            
            codigo_processo = regex_processo.search(processo).group(0)
            lista_ativos = regex_parte_ativa.findall(processo)
            lista_passivos = regex_parte_passiva.findall(processo)
            lista_advogados = regex_advogados.findall(processo)
            lista_neutros = regex_parte_neutra.findall(processo)

            conteudo = re.sub('\n', '', processo, re.MULTILINE)
            conteudo = re.sub(';', ' - ', conteudo, re.MULTILINE)
            conteudo = re.sub(r'\d{7}-\d{2}.\d{4}.\d.\d{2}.\d{4}', '', conteudo, re.DOTALL)
            conteudo = re.sub(r'(Apelante:.*?- |Requerente:.*?- )', '', conteudo, re.DOTALL)
            conteudo = re.sub(r'(Apelad[o|a]:.*?- |Requeri[o|a]:.*?- )', '', conteudo, re.DOTALL)
            conteudo = re.sub(r'(Advs:.*|Advogad(o|a):.*)', '', conteudo, re.DOTALL)
            conteudo = re.sub(r'(Apd(o|a)\/Apte:).*?-|(Apte\/Apd(o|a):).*?-', '', conteudo, re.DOTALL)

            lista_hifen = conteudo.split(' - ')
            meio_processo = lista_hifen[1]
            natureza_processo = lista_hifen[2]
            comarca = lista_hifen[3]

            conteudo = re.sub('- ' + lista_hifen[1] + ' - ', '', conteudo, re.DOTALL)
            conteudo = re.sub(lista_hifen[2] + ' - ', '', conteudo, re.DOTALL)
            conteudo = re.sub(lista_hifen[3] + ' - ', '', conteudo, re.DOTALL)
            
            tupla = (codigo_processo, 
                     meio_processo, 
                     natureza_processo, 
                     comarca,
                     ' '.join(lista_ativos),
                     ' '.join(lista_passivos),                     
                     ' '.join(lista_neutros),
                     ' '.join(lista_advogados),
                     conteudo,
                     processo)
            lista_apelacoes_danos_morais.append(tupla)
        except:            
            import pdb; pdb.set_trace()
            print('erro na extração de entidades do processo {}'.format(e))
len(lista_apelacoes_danos_morais)
# Out:
# 109

# %% [markdown]
# ### Transformação dos dados em DataFrame

# %%
import pandas as pd
df = pd.DataFrame.from_records(lista_apelacoes_danos_morais)
df.columns = ['codigo_processo', 'meio_processo', 'natureza_processo', 'comarca','lista_ativos','lista_passivos', 'lista_neutros', 'lista_advogados','conteudo', 'texto_original']
df.to_excel('apelacoes_danos_morais_mvp_0.1.xls')
df
# Out:
#                codigo_processo  \
# 0    1017652-30.2017.8.26.0224
# 1    1021447-91.2018.8.26.0100
# 2    0000876-31.2011.8.26.0240
# 3    1036296-76.2015.8.26.0002
# 4    1008894-85.2016.8.26.0066
# 5    1010932-84.2015.8.26.0008
# 6    1014218-69.2016.8.26.0482
# 7    1001544-32.2016.8.26.0394
# 8    1024324-04.2018.8.26.0100
# 9    1115926-13.2017.8.26.0100
# 10   1112929-62.2014.8.26.0100
# 11   1011765-60.2017.8.26.0161
# 12   1102667-19.2015.8.26.0100
# 13   1021601-60.2015.8.26.0506
# 14   1025980-30.2017.8.26.0100
# 15   1000581-26.2017.8.26.0576
# 16   1001822-88.2016.8.26.0408
# 17   1013560-37.2016.8.26.0032
# 18   1000836-44.2018.8.26.0286
# 19   0000410-89.2005.8.26.0323
# 20   0001717-35.2014.8.26.0300
# 21   0004178-14.2013.8.26.0009
# 22   0011473-90.2011.8.26.0068
# 23   0602690-67.2008.8.26.0229
# 24   0000505-84.2015.8.26.0383
# 25   0001598-84.2013.8.26.0114
# 26   0024994-27.2012.8.26.0114
# 27   0128715-37.2012.8.26.0100
# 28   0180695-23.2012.8.26.0100
# 29   0000648-79.2014.8.26.0069
# ..                         ...
# 79   0014578-22.2014.8.26.0084
# 80   0036020-56.2011.8.26.0114
# 81   1005903-65.2016.8.26.0704
# 82   1030747-20.2016.8.26.0562
# 83   1000661-86.2016.8.26.0426
# 84   1002121-06.2017.8.26.0481
# 85   1003929-38.2017.8.26.0322
# 86   1004195-59.2016.8.26.0322
# 87   1006109-33.2017.8.26.0223
# 88   1006521-82.2017.8.26.0604
# 89   1006959-64.2017.8.26.0554
# 90   1007528-05.2017.8.26.0477
# 91   1012558-26.2013.8.26.0068
# 92   1027688-45.2017.8.26.0576
# 93   1030702-27.2015.8.26.0602
# 94   1032545-56.2017.8.26.0602
# 95   1032798-22.2017.8.26.0577
# 96   1062936-82.2016.8.26.0002
# 97   1113571-64.2016.8.26.0100
# 98   1053050-61.2013.8.26.0100
# 99   1001627-30.2017.8.26.0615
# 100  1003104-19.2018.8.26.0077
# 101  1008652-53.2018.8.26.0100
# 102  1022325-50.2017.8.26.0003
# 103  0000571-63.2015.8.26.0060
# 28    Magistrado(a) José Joaquim dos Santos - Negar...
# 29    Magistrado(a) Marcus Vinicius Rios Gonçalves ...
# ..                                                 ...
# 79      Magistrado(a) Cesar Luiz de Almeida - Negar...
# 80    Magistrado(a) Cesar Luiz de Almeida - Deram p...
# 81    Magistrado(a) Lino Machado - Negaram provimen...
# 82    Magistrado(a) Lino Machado - Negaram provimen...
# 83    Magistrado(a) Flavio Abramovici - Deram parci...
# 84    Magistrado(a) Flavio Abramovici - Negaram pro...
# 85    Magistrado(a) Flavio Abramovici - Deram parci...
# 86    Magistrado(a) Flavio Abramovici - Negaram pro...
# 87    Magistrado(a) Flavio Abramovici - Deram parci...
# 88    Magistrado(a) Flavio Abramovici - Negaram pro...
# 89    Magistrado(a) Melo Bueno - Negaram provimento...
# 90    Magistrado(a) Flavio Abramovici - Deram parci...
# 91    Magistrado(a) Flavio Abramovici - Deram provi...
# 92    Magistrado(a) Melo Bueno - Negaram provimento...
# 93    Magistrado(a) Melo Bueno - Afastaram a extinç...
# 94    Magistrado(a) Flavio Abramovici - Deram parci...
# 95    Magistrado(a) Flavio Abramovici - Negaram pro...
# 96    Magistrado(a) Flavio Abramovici - Deram parci...
# 97    Magistrado(a) Flavio Abramovici - Deram parci...
# 98    Magistrado(a) Israel Góes dos Anjos - Julgara...
# 99      Magistrado(a) Eduardo Siqueira - RECURSO DO...
# 100   Magistrado(a) Eduardo Siqueira - Deram provim...
# 101   Magistrado(a) Spencer Almeida Ferreira - Dera...
# 102   Magistrado(a) Eduardo Siqueira - Negaram prov...
# 103   Magistrado(a) Aliende Ribeiro - Negaram provi...
# 104   Magistrado(a) Reinaldo Miluzzi - Deram parcia...
# 105   Magistrado(a) Paulo Dimas Mascaretti - Negara...
# 106   Magistrado(a) Paulo Dimas Mascaretti - Negara...
# 107   Magistrado(a) Paulo Dimas Mascaretti - Deram ...
# 108   Magistrado(a) José Maria Câmara Junior - Dera...
#
#                                         texto_original
# 0    1017652-30.2017.8.26.0224 - Processo Digital. ...
# 1    1021447-91.2018.8.26.0100 - Processo Digital. ...
# 2    0000876-31.2011.8.26.0240 - Processo Físico - ...
# 3    1036296-76.2015.8.26.0002 - Processo Digital. ...
# 4    1008894-85.2016.8.26.0066 - Processo Digital. ...
# 5    1010932-84.2015.8.26.0008 - Processo Digital. ...
# 6    1014218-69.2016.8.26.0482 - Processo Digital. ...
# 7    1001544-32.2016.8.26.0394 - Processo Digital. ...
# 8    1024324-04.2018.8.26.0100 - Processo Digital. ...
# 9    1115926-13.2017.8.26.0100 - Processo Digital. ...
# 10   1112929-62.2014.8.26.0100 - Processo Digital. ...
# 11   1011765-60.2017.8.26.0161 - Processo Digital. ...
# 12   1102667-19.2015.8.26.0100 - Processo Digital. ...
# 13   1021601-60.2015.8.26.0506 - Processo Digital. ...
# 14   1025980-30.2017.8.26.0100 - Processo Digital. ...
# 15   1000581-26.2017.8.26.0576 - Processo Digital. ...
# 16   1001822-88.2016.8.26.0408 - Processo Digital. ...
# 17   1013560-37.2016.8.26.0032 - Processo Digital. ...
# 18   1000836-44.2018.8.26.0286 - Processo Digital. ...
# 19   0000410-89.2005.8.26.0323 - Processo Físico - ...
# 20   0001717-35.2014.8.26.0300 - Processo Físico - ...
# 21   0004178-14.2013.8.26.0009 - Processo Físico - ...
# 22   0011473-90.2011.8.26.0068 - Processo Físico - ...
# 23   0602690-67.2008.8.26.0229 - Processo Físico - ...
# 24   0000505-84.2015.8.26.0383 - Processo Físico - ...
# 25   0001598-84.2013.8.26.0114 - Processo Físico - ...
# 26   0024994-27.2012.8.26.0114 - Processo Físico - ...
# 27   0128715-37.2012.8.26.0100 - Processo Físico - ...
# 28   0180695-23.2012.8.26.0100 - Processo Físico - ...
# 29   0000648-79.2014.8.26.0069 - Processo Físico - ...
# ..                                                 ...
# 79   0014578-22.2014.8.26.0084 - Processo Físico - ...
# 80   0036020-56.2011.8.26.0114 - Processo Físico - ...
# 81   1005903-65.2016.8.26.0704 - Processo Digital. ...
# 82   1030747-20.2016.8.26.0562 - Processo Digital. ...
# 83   1000661-86.2016.8.26.0426 - Processo Digital. ...
# 84   1002121-06.2017.8.26.0481 - Processo Digital. ...
# 85   1003929-38.2017.8.26.0322 - Processo Digital. ...
# 86   1004195-59.2016.8.26.0322 - Processo Digital. ...
# 87   1006109-33.2017.8.26.0223 - Processo Digital. ...
# 88   1006521-82.2017.8.26.0604 - Processo Digital. ...
# 89   1006959-64.2017.8.26.0554 - Processo Digital. ...
# 90   1007528-05.2017.8.26.0477 - Processo Digital. ...
# 91   1012558-26.2013.8.26.0068 - Processo Digital. ...
# 92   1027688-45.2017.8.26.0576 - Processo Digital. ...
# 93   1030702-27.2015.8.26.0602 - Processo Digital. ...
# 94   1032545-56.2017.8.26.0602 - Processo Digital. ...
# 95   1032798-22.2017.8.26.0577 - Processo Digital. ...
# 96   1062936-82.2016.8.26.0002 - Processo Digital. ...
# 97   1113571-64.2016.8.26.0100 - Processo Digital. ...
# 98   1053050-61.2013.8.26.0100 - Processo Digital. ...
# 99   1001627-30.2017.8.26.0615 - Processo Digital. ...
# 100  1003104-19.2018.8.26.0077 - Processo Digital. ...
# 101  1008652-53.2018.8.26.0100 - Processo Digital. ...
# 102  1022325-50.2017.8.26.0003 - Processo Digital. ...
# 103  0000571-63.2015.8.26.0060 - Processo Físico - ...
# 104  1010423-34.2017.8.26.0510 - Processo Digital. ...
# 105  1001168-83.2016.8.26.0414 - Processo Digital. ...
# 106  1010668-33.2016.8.26.0590 - Processo Digital. ...
# 107  1038367-24.2017.8.26.0053 - Processo Digital. ...
# 108  1043621-12.2016.8.26.0053 - Processo Digital. ...
#
# [109 rows x 10 columns]

# %%
def parsear_caderno_segunda(caderno):
    raw = parser.from_file(caderno)
    #remove quebras de páginas
    reg_quebra_pagina = re.compile('(\\n){4}Publicação Oficial do Tribunal de Justiça do Estado de São Paulo - Lei Federal nº 11.419/06, art. 4º(\\n){2}Disponibilização:.*?(\\n){2}')
    conteudo_pdf = reg_quebra_pagina.sub(' ', raw['content'])
    #quebra o documento pdf em uma lista de processos onde cada elemento é o conteúdo de um processo
    regex_processos = re.compile('(?<=Nº )\d{7}-\d{2}.\d{4}.\d.\d{2}.\d{4}.*?(?=\n{2})', re.DOTALL)
    lista_processos = regex_processos.findall(conteudo_pdf)
    
    ##EXTRACAO DE ENTIDADES DOS PROCESSOS###
    
    regex_processo = re.compile(r'\d{7}-\d{2}.\d{4}.\d.\d{2}.\d{4}', re.DOTALL)
    regex_parte_ativa = re.compile(r'(?<=Apelante:).*?(?=-)|(?<=Requerente:).*?(?=-)|(?<=Agravante:).*?(?=-)', re.DOTALL)
    regex_parte_passiva = re.compile(r'(?<=Apelad[o|a]:).*?(?=-)|(?<=Requeri[o|a]:).*?(?=-)|(?<=Agravad[o|a]:).*?(?=-)', re.DOTALL)
    regex_parte_neutra = re.compile(r'(?<=Apd[o|a]\/Apte:).*?(?=-)|(?<=Apte\/Apd[o|a]:).*?(?=-)')
    regex_advogados = re.compile(r'(?<=Advs:).*|(?<=Advogad[o|a]:).*', re.DOTALL)

    lista_apelacoes_danos_morais = []

    for i, processo in enumerate(lista_processos, 0):
        if re.search('- Apelação -', processo, 
                     re.MULTILINE) != None and re.search('danos morais', 
                                                         processo.lower(),
                                                         re.MULTILINE) != None:        
            try:            
                codigo_processo = regex_processo.search(processo).group(0)
                lista_ativos = regex_parte_ativa.findall(processo)
                lista_passivos = regex_parte_passiva.findall(processo)
                lista_advogados = regex_advogados.findall(processo)
                lista_neutros = regex_parte_neutra.findall(processo)

                conteudo = re.sub('\n', '', processo, re.MULTILINE)
                conteudo = re.sub(';', ' - ', conteudo, re.MULTILINE)
                conteudo = re.sub(r'\d{7}-\d{2}.\d{4}.\d.\d{2}.\d{4}', '', conteudo, re.DOTALL)
                conteudo = re.sub(r'(Apelante:.*?- |Requerente:.*?- )', '', conteudo, re.DOTALL)
                conteudo = re.sub(r'(Apelad[o|a]:.*?- |Requeri[o|a]:.*?- )', '', conteudo, re.DOTALL)
                conteudo = re.sub(r'(Advs:.*|Advogad(o|a):.*)', '', conteudo, re.DOTALL)
                conteudo = re.sub(r'(Apd(o|a)\/Apte:).*?-|(Apte\/Apd(o|a):).*?-', '', conteudo, re.DOTALL)

                lista_hifen = conteudo.split(' - ')
                meio_processo = lista_hifen[1]
                natureza_processo = lista_hifen[2]
                comarca = lista_hifen[3]

                conteudo = re.sub('- ' + lista_hifen[1] + ' - ', '', conteudo, re.DOTALL)
                conteudo = re.sub(lista_hifen[2] + ' - ', '', conteudo, re.DOTALL)
                conteudo = re.sub(lista_hifen[3] + ' - ', '', conteudo, re.DOTALL)

                tupla = (codigo_processo, 
                         meio_processo, 
                         natureza_processo, 
                         comarca,
                         ' '.join(lista_ativos),
                         ' '.join(lista_passivos),                     
                         ' '.join(lista_neutros),
                         ' '.join(lista_advogados),
                         conteudo,
                         processo)
                lista_apelacoes_danos_morais.append(tupla)
            except:            
                print('erro na extração de entidades do processo {}'.format(codigo_processo))
    
    df = pd.DataFrame.from_records(lista_apelacoes_danos_morais)
    df.columns = ['codigo_processo', 'meio_processo', 'natureza_processo', 'comarca','lista_ativos','lista_passivos', 'lista_neutros', 'lista_advogados','conteudo', 'texto_original']
    return df
